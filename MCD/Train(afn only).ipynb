# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from DataRead import data_read
from OriginModel import *
import time
import numpy as np

# %%
## hyper parameters
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
IsSave = False
num_classes = 34
epoch = 30
batch_size = 32
learning_rate = 0.0001
interval=100
optimizer='adam'
num_k=4
save_epoch=10
seed = 1
datapath = '/home/zsc/ADS_B_select_files_/dataset/noise_64x64_202004xx_to_202011xx.h5'
stime = str(time.asctime( time.localtime(time.time()) )).split(' ')
record_file = './record/'+ stime[-4]+stime[-3]+ '_' +stime[-2]
print(record_file)
# Out:
# ./record/2_23:42:28

# %%
datasets, dataset_test = data_read(batch_size,datapath)



G = Feature().to(device)
C1 = Predictor(num_classes=num_classes).to(device)
# C2 = Predictor(num_classes=num_classes).to(device)

opt_g = optim.Adam(G.parameters(),lr=learning_rate, weight_decay=0.0005)
opt_c1 = optim.Adam(C1.parameters(),lr=learning_rate, weight_decay=0.0005)
# opt_c2 = optim.Adam(C2.parameters(),lr=learning_rate, weight_decay=0.0005)

# %%
def entropy(predictions: torch.Tensor, reduction='none') -> torch.Tensor:
    epsilon = 1e-5
    H = -predictions * torch.log(predictions + epsilon)
    H = H.sum(dim=1)
    if reduction == 'mean':
        return H.mean()
    else:
        return H

def discrepancy(out1, out2):
    return torch.mean(torch.abs(F.softmax(out1,dim=1) - F.softmax(out2,dim=1)))

def mccLoss(logits: torch.Tensor,temperature=1) -> torch.Tensor:
    batch_size, num_classes = logits.shape
    predictions = F.softmax(logits / temperature, dim=1)  # batch_size x num_classes
    entropy_weight = entropy(predictions).detach()
    entropy_weight = 1 + torch.exp(-entropy_weight)
    entropy_weight = (batch_size * entropy_weight / torch.sum(entropy_weight)).unsqueeze(dim=1)  # batch_size x 1
    class_confusion_matrix = torch.mm((predictions * entropy_weight).transpose(1, 0), predictions) # num_classes x num_classes
    class_confusion_matrix = class_confusion_matrix / torch.sum(class_confusion_matrix, dim=1)
    mcc_loss = (torch.sum(class_confusion_matrix) - torch.trace(class_confusion_matrix)) / num_classes
    return mcc_loss

def get_L2norm_loss_self_driven(x, radius = 25., weight_L2norm= 0.05):
    l = (x.norm(p=2, dim=1).mean() - radius) ** 2
    return weight_L2norm * l

# %%
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
bestacc = 0
bestmat = np.zeros((34,34))
for i in range(epoch):
    criterion = nn.CrossEntropyLoss().to(device)
    G.train()
    C1.train()
    # C2.train()
    torch.cuda.manual_seed(seed)
    if (i+1) % 5 == 0:
            learning_rate /= 2
            update_lr(opt_g, learning_rate)
            update_lr(opt_c1, learning_rate)
            # update_lr(opt_c2, learning_rate)
    for batch_idx, data in enumerate(datasets):
        img_t = data['T']
        img_s = data['S']
        label_s = data['S_label'].to(device)
        img_s = img_s.to(device)
        img_t = img_t.to(device)
        opt_g.zero_grad()
        opt_c1.zero_grad()
        # opt_c2.zero_grad()
        feat_s = G(img_s)
        output_s1 = C1(feat_s)
        # output_s2 = C2(feat_s)
        feat_t = G(img_t)
        # mccloss_s1 = mccLoss(output_s1)
        # mccloss_s2 = mccLoss(output_s2)

        loss_s1 = criterion(output_s1, label_s)
        # loss_s2 = criterion(output_s2, label_s)
        afnloss = get_L2norm_loss_self_driven(feat_s) + get_L2norm_loss_self_driven(feat_t)

        loss = loss_s1 + afnloss

        loss.backward()
        opt_g.step()
        opt_c1.step()
        # opt_c2.step()

        opt_g.zero_grad()
        opt_c1.zero_grad()
        # opt_c2.zero_grad()


        if batch_idx % interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss1: {:.6f}\t mccloss_t1: {:.6f} '.format(
                    i, batch_idx, 500,
                    100. * batch_idx / 500, loss_s1.item(), afnloss.item()))
            if record_file:
                    with open(record_file , 'a+') as f:
                        f.write('Loss1: {:.6f}\t mccloss_t1: {:.6f}\n'.format(loss_s1.item(), afnloss.item()))
    
    #  TEST
    G.eval()
    C1.eval()
    # C2.eval()
    test_loss = 0
    correct1 = 0

    size = 0
    
    mat = np.zeros((34,34))
    with torch.no_grad():
        for batch_idx, data in enumerate(dataset_test):
            img = data['T']
            label = data['T_label']
            img, label = img.to(device), label.to(device)
            feat = G(img)
            output1 = C1(feat)
            # output2 = C2(feat)
            test_loss += F.nll_loss(output1, label).item()
            pred1 = output1.data.max(1)[1]
            k = label.data.size()[0]
            correct1 += pred1.eq(label.data).cpu().sum()

            size += k
            for i,X in enumerate(pred1):
                preL = int(X.cpu().detach().numpy())
                trueL = int(label.data[i].cpu().detach().numpy())
                mat[trueL,preL] += 1
        test_loss = test_loss / size
        print('\nTest set: Average loss: {:.4f}, Accuracy : {}/{} ({:.2f}%)  \n'.format(
                test_loss, correct1, size,100. * correct1 / size))
        if 100. * correct1 / size > bestacc:
            bestacc = 100. * correct1 / size
            bestmat = mat
    if  IsSave and (i+1) % save_epoch == 0:
        torch.save(G,
                './MCDmodel/'+record_file.split('/')[-1]+'_G_mcconly.pt')
        torch.save(C1,
                './MCDmodel/'+record_file.split('/')[-1]+'_C1_mcconly.pt')
        
    if record_file:
        print('recording :', record_file)
        with open(record_file,'a+') as f:
            f.write(' Accuracy : {}/{} ({:.2f}%)\n'.format(correct1 , size,correct1 /size))
# Out:
# Train Epoch: 0 [0/500 (0%)]	Loss1: 3.520294	 mccloss_t1: 38.841167
# Train Epoch: 0 [100/500 (20%)]	Loss1: 2.907602	 mccloss_t1: 0.063671
# Train Epoch: 0 [200/500 (40%)]	Loss1: 2.273857	 mccloss_t1: 0.020663
# Train Epoch: 0 [300/500 (60%)]	Loss1: 1.992605	 mccloss_t1: 0.021969
# Train Epoch: 0 [400/500 (80%)]	Loss1: 2.132135	 mccloss_t1: 0.017375
#
# Test set: Average loss: -0.0264, Accuracy : 1914/14395 (13.30%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 1 [0/500 (0%)]	Loss1: 1.710476	 mccloss_t1: 0.109155
# Train Epoch: 1 [100/500 (20%)]	Loss1: 1.499330	 mccloss_t1: 0.027512
# Train Epoch: 1 [200/500 (40%)]	Loss1: 0.842797	 mccloss_t1: 0.031570
# Train Epoch: 1 [300/500 (60%)]	Loss1: 0.798504	 mccloss_t1: 0.002455
# Train Epoch: 1 [400/500 (80%)]	Loss1: 0.582021	 mccloss_t1: 0.000056
#
# Test set: Average loss: -0.0994, Accuracy : 8385/14395 (58.25%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 2 [0/500 (0%)]	Loss1: 0.621788	 mccloss_t1: 0.033936
# Train Epoch: 2 [100/500 (20%)]	Loss1: 0.265183	 mccloss_t1: 0.031885
# Train Epoch: 2 [200/500 (40%)]	Loss1: 0.082245	 mccloss_t1: 0.002772
# Train Epoch: 2 [300/500 (60%)]	Loss1: 0.165326	 mccloss_t1: 0.000565
# Train Epoch: 2 [400/500 (80%)]	Loss1: 0.142616	 mccloss_t1: 0.012728
#
# Test set: Average loss: -0.1326, Accuracy : 10160/14395 (70.58%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 3 [0/500 (0%)]	Loss1: 0.075151	 mccloss_t1: 0.001429
# Train Epoch: 3 [100/500 (20%)]	Loss1: 0.121291	 mccloss_t1: 0.019213
# Train Epoch: 3 [200/500 (40%)]	Loss1: 0.047555	 mccloss_t1: 0.001805
# Train Epoch: 3 [300/500 (60%)]	Loss1: 0.065871	 mccloss_t1: 0.000352
# Train Epoch: 3 [400/500 (80%)]	Loss1: 0.018713	 mccloss_t1: 0.004756
#
# Test set: Average loss: -0.1595, Accuracy : 10931/14395 (75.94%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 4 [0/500 (0%)]	Loss1: 0.037917	 mccloss_t1: 0.003230
# Train Epoch: 4 [100/500 (20%)]	Loss1: 0.012310	 mccloss_t1: 0.002973
# Train Epoch: 4 [200/500 (40%)]	Loss1: 0.021045	 mccloss_t1: 0.003121
# Train Epoch: 4 [300/500 (60%)]	Loss1: 0.005603	 mccloss_t1: 0.003592
# Train Epoch: 4 [400/500 (80%)]	Loss1: 0.012231	 mccloss_t1: 0.001797
#
# Test set: Average loss: -0.1742, Accuracy : 11493/14395 (79.84%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 5 [0/500 (0%)]	Loss1: 0.177477	 mccloss_t1: 0.003948
# Train Epoch: 5 [100/500 (20%)]	Loss1: 0.010279	 mccloss_t1: 0.001496
# Train Epoch: 5 [200/500 (40%)]	Loss1: 0.006006	 mccloss_t1: 0.000983
# Train Epoch: 5 [300/500 (60%)]	Loss1: 0.007363	 mccloss_t1: 0.000595
# Train Epoch: 5 [400/500 (80%)]	Loss1: 0.005814	 mccloss_t1: 0.000099
#
# Test set: Average loss: -0.1768, Accuracy : 11646/14395 (80.90%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 6 [0/500 (0%)]	Loss1: 0.005631	 mccloss_t1: 0.000569
# Train Epoch: 6 [100/500 (20%)]	Loss1: 0.004166	 mccloss_t1: 0.001988
# Train Epoch: 6 [200/500 (40%)]	Loss1: 0.006313	 mccloss_t1: 0.002850
# Train Epoch: 6 [300/500 (60%)]	Loss1: 0.004164	 mccloss_t1: 0.000052
# Train Epoch: 6 [400/500 (80%)]	Loss1: 0.005163	 mccloss_t1: 0.000003
#
# Test set: Average loss: -0.1810, Accuracy : 11760/14395 (81.70%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 7 [0/500 (0%)]	Loss1: 0.008385	 mccloss_t1: 0.000543
# Train Epoch: 7 [100/500 (20%)]	Loss1: 0.004505	 mccloss_t1: 0.000930
# Train Epoch: 7 [200/500 (40%)]	Loss1: 0.003285	 mccloss_t1: 0.000164
# Train Epoch: 7 [300/500 (60%)]	Loss1: 0.003807	 mccloss_t1: 0.002680
# Train Epoch: 7 [400/500 (80%)]	Loss1: 0.006803	 mccloss_t1: 0.000916
#
# Test set: Average loss: -0.1857, Accuracy : 11772/14395 (81.78%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 8 [0/500 (0%)]	Loss1: 0.004470	 mccloss_t1: 0.000451
# Train Epoch: 8 [100/500 (20%)]	Loss1: 0.003836	 mccloss_t1: 0.000739
# Train Epoch: 8 [200/500 (40%)]	Loss1: 0.006090	 mccloss_t1: 0.000194
# Train Epoch: 8 [300/500 (60%)]	Loss1: 0.013548	 mccloss_t1: 0.000061
# Train Epoch: 8 [400/500 (80%)]	Loss1: 0.003619	 mccloss_t1: 0.000145
#
# Test set: Average loss: -0.1387, Accuracy : 8949/14395 (62.17%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 9 [0/500 (0%)]	Loss1: 0.182941	 mccloss_t1: 0.000803
# Train Epoch: 9 [100/500 (20%)]	Loss1: 0.013654	 mccloss_t1: 0.000454
# Train Epoch: 9 [200/500 (40%)]	Loss1: 0.021824	 mccloss_t1: 0.002980
# Train Epoch: 9 [300/500 (60%)]	Loss1: 0.003643	 mccloss_t1: 0.001636
# Train Epoch: 9 [400/500 (80%)]	Loss1: 0.004902	 mccloss_t1: 0.001533
#
# Test set: Average loss: -0.1671, Accuracy : 11530/14395 (80.10%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 10 [0/500 (0%)]	Loss1: 0.005435	 mccloss_t1: 0.000749
# Train Epoch: 10 [100/500 (20%)]	Loss1: 0.002938	 mccloss_t1: 0.000364
# Train Epoch: 10 [200/500 (40%)]	Loss1: 0.007816	 mccloss_t1: 0.000903
# Train Epoch: 10 [300/500 (60%)]	Loss1: 0.003640	 mccloss_t1: 0.001653
# Train Epoch: 10 [400/500 (80%)]	Loss1: 0.002962	 mccloss_t1: 0.002667
#
# Test set: Average loss: -0.1904, Accuracy : 12008/14395 (83.42%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 11 [0/500 (0%)]	Loss1: 0.003276	 mccloss_t1: 0.000761
# Train Epoch: 11 [100/500 (20%)]	Loss1: 0.003923	 mccloss_t1: 0.000026
# Train Epoch: 11 [200/500 (40%)]	Loss1: 0.004227	 mccloss_t1: 0.000404
# Train Epoch: 11 [300/500 (60%)]	Loss1: 0.002497	 mccloss_t1: 0.000069
# Train Epoch: 11 [400/500 (80%)]	Loss1: 0.002591	 mccloss_t1: 0.000506
#
# Test set: Average loss: -0.1941, Accuracy : 12084/14395 (83.95%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 12 [0/500 (0%)]	Loss1: 0.001953	 mccloss_t1: 0.000051
# Train Epoch: 12 [100/500 (20%)]	Loss1: 0.002529	 mccloss_t1: 0.001362
# Train Epoch: 12 [200/500 (40%)]	Loss1: 0.003697	 mccloss_t1: 0.001620
# Train Epoch: 12 [300/500 (60%)]	Loss1: 0.004995	 mccloss_t1: 0.000388
# Train Epoch: 12 [400/500 (80%)]	Loss1: 0.002653	 mccloss_t1: 0.000010
#
# Test set: Average loss: -0.1943, Accuracy : 12123/14395 (84.22%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 13 [0/500 (0%)]	Loss1: 0.001914	 mccloss_t1: 0.000514
# Train Epoch: 13 [100/500 (20%)]	Loss1: 0.002481	 mccloss_t1: 0.000220
# Train Epoch: 13 [200/500 (40%)]	Loss1: 0.001906	 mccloss_t1: 0.001608
# Train Epoch: 13 [300/500 (60%)]	Loss1: 0.001859	 mccloss_t1: 0.000154
# Train Epoch: 13 [400/500 (80%)]	Loss1: 0.001554	 mccloss_t1: 0.000169
#
# Test set: Average loss: -0.1969, Accuracy : 12112/14395 (84.14%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 14 [0/500 (0%)]	Loss1: 0.001983	 mccloss_t1: 0.000226
# Train Epoch: 14 [100/500 (20%)]	Loss1: 0.003575	 mccloss_t1: 0.000059
# Train Epoch: 14 [200/500 (40%)]	Loss1: 0.002098	 mccloss_t1: 0.000413
# Train Epoch: 14 [300/500 (60%)]	Loss1: 0.002613	 mccloss_t1: 0.000229
# Train Epoch: 14 [400/500 (80%)]	Loss1: 0.002121	 mccloss_t1: 0.000012
#
# Test set: Average loss: -0.1975, Accuracy : 12219/14395 (84.88%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 15 [0/500 (0%)]	Loss1: 0.001538	 mccloss_t1: 0.000771
# Train Epoch: 15 [100/500 (20%)]	Loss1: 0.001958	 mccloss_t1: 0.000011
# Train Epoch: 15 [200/500 (40%)]	Loss1: 0.003209	 mccloss_t1: 0.000356
# Train Epoch: 15 [300/500 (60%)]	Loss1: 0.002199	 mccloss_t1: 0.000496
# Train Epoch: 15 [400/500 (80%)]	Loss1: 0.001704	 mccloss_t1: 0.000277
#
# Test set: Average loss: -0.1986, Accuracy : 12213/14395 (84.84%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 16 [0/500 (0%)]	Loss1: 0.000984	 mccloss_t1: 0.000100
# Train Epoch: 16 [100/500 (20%)]	Loss1: 0.001050	 mccloss_t1: 0.000065
# Train Epoch: 16 [200/500 (40%)]	Loss1: 0.001455	 mccloss_t1: 0.000022
# Train Epoch: 16 [300/500 (60%)]	Loss1: 0.001875	 mccloss_t1: 0.000093
# Train Epoch: 16 [400/500 (80%)]	Loss1: 0.002112	 mccloss_t1: 0.000341
#
# Test set: Average loss: -0.1999, Accuracy : 12274/14395 (85.27%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 17 [0/500 (0%)]	Loss1: 0.002448	 mccloss_t1: 0.000471
# Train Epoch: 17 [100/500 (20%)]	Loss1: 0.001511	 mccloss_t1: 0.000010
# Train Epoch: 17 [200/500 (40%)]	Loss1: 0.001800	 mccloss_t1: 0.000310
# Train Epoch: 17 [300/500 (60%)]	Loss1: 0.002643	 mccloss_t1: 0.000026
# Train Epoch: 17 [400/500 (80%)]	Loss1: 0.001125	 mccloss_t1: 0.000080
#
# Test set: Average loss: -0.1978, Accuracy : 12262/14395 (85.18%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 18 [0/500 (0%)]	Loss1: 0.003524	 mccloss_t1: 0.000059
# Train Epoch: 18 [100/500 (20%)]	Loss1: 0.001543	 mccloss_t1: 0.000050
# Train Epoch: 18 [200/500 (40%)]	Loss1: 0.001652	 mccloss_t1: 0.000152
# Train Epoch: 18 [300/500 (60%)]	Loss1: 0.001245	 mccloss_t1: 0.000198
# Train Epoch: 18 [400/500 (80%)]	Loss1: 0.001252	 mccloss_t1: 0.000194
#
# Test set: Average loss: -0.2026, Accuracy : 12344/14395 (85.75%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 19 [0/500 (0%)]	Loss1: 0.001161	 mccloss_t1: 0.000645
# Train Epoch: 19 [100/500 (20%)]	Loss1: 0.002452	 mccloss_t1: 0.000330
# Train Epoch: 19 [200/500 (40%)]	Loss1: 0.002748	 mccloss_t1: 0.000145
# Train Epoch: 19 [300/500 (60%)]	Loss1: 0.013422	 mccloss_t1: 0.000011
# Train Epoch: 19 [400/500 (80%)]	Loss1: 0.002070	 mccloss_t1: 0.000381
#
# Test set: Average loss: -0.2015, Accuracy : 12377/14395 (85.98%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 20 [0/500 (0%)]	Loss1: 0.002024	 mccloss_t1: 0.000042
# Train Epoch: 20 [100/500 (20%)]	Loss1: 0.001790	 mccloss_t1: 0.000217
# Train Epoch: 20 [200/500 (40%)]	Loss1: 0.002044	 mccloss_t1: 0.000116
# Train Epoch: 20 [300/500 (60%)]	Loss1: 0.001985	 mccloss_t1: 0.000177
# Train Epoch: 20 [400/500 (80%)]	Loss1: 0.002065	 mccloss_t1: 0.000046
#
# Test set: Average loss: -0.1932, Accuracy : 12080/14395 (83.92%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 21 [0/500 (0%)]	Loss1: 0.005685	 mccloss_t1: 0.000152
# Train Epoch: 21 [100/500 (20%)]	Loss1: 0.003494	 mccloss_t1: 0.000156
# Train Epoch: 21 [200/500 (40%)]	Loss1: 0.001377	 mccloss_t1: 0.000021
# Train Epoch: 21 [300/500 (60%)]	Loss1: 0.002124	 mccloss_t1: 0.000108
# Train Epoch: 21 [400/500 (80%)]	Loss1: 0.001839	 mccloss_t1: 0.000040
#
# Test set: Average loss: -0.2030, Accuracy : 12327/14395 (85.63%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 22 [0/500 (0%)]	Loss1: 0.001682	 mccloss_t1: 0.000554
# Train Epoch: 22 [100/500 (20%)]	Loss1: 0.001377	 mccloss_t1: 0.000122
# Train Epoch: 22 [200/500 (40%)]	Loss1: 0.001576	 mccloss_t1: 0.000033
# Train Epoch: 22 [300/500 (60%)]	Loss1: 0.001110	 mccloss_t1: 0.000062
# Train Epoch: 22 [400/500 (80%)]	Loss1: 0.002566	 mccloss_t1: 0.000072
#
# Test set: Average loss: -0.2039, Accuracy : 12392/14395 (86.09%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 23 [0/500 (0%)]	Loss1: 0.001843	 mccloss_t1: 0.000033
# Train Epoch: 23 [100/500 (20%)]	Loss1: 0.001380	 mccloss_t1: 0.000098
# Train Epoch: 23 [200/500 (40%)]	Loss1: 0.002034	 mccloss_t1: 0.000261
# Train Epoch: 23 [300/500 (60%)]	Loss1: 0.001686	 mccloss_t1: 0.000091
# Train Epoch: 23 [400/500 (80%)]	Loss1: 0.000829	 mccloss_t1: 0.000041
#
# Test set: Average loss: -0.2049, Accuracy : 12371/14395 (85.94%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 24 [0/500 (0%)]	Loss1: 0.000991	 mccloss_t1: 0.000068
# Train Epoch: 24 [100/500 (20%)]	Loss1: 0.001916	 mccloss_t1: 0.000076
# Train Epoch: 24 [200/500 (40%)]	Loss1: 0.000913	 mccloss_t1: 0.000110
# Train Epoch: 24 [300/500 (60%)]	Loss1: 0.001024	 mccloss_t1: 0.000218
# Train Epoch: 24 [400/500 (80%)]	Loss1: 0.001537	 mccloss_t1: 0.000284
#
# Test set: Average loss: -0.2067, Accuracy : 12429/14395 (86.34%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 25 [0/500 (0%)]	Loss1: 0.001153	 mccloss_t1: 0.000009
# Train Epoch: 25 [100/500 (20%)]	Loss1: 0.000974	 mccloss_t1: 0.000002
# Train Epoch: 25 [200/500 (40%)]	Loss1: 0.001126	 mccloss_t1: 0.000038
# Train Epoch: 25 [300/500 (60%)]	Loss1: 0.002229	 mccloss_t1: 0.000193
# Train Epoch: 25 [400/500 (80%)]	Loss1: 0.001839	 mccloss_t1: 0.000217
#
# Test set: Average loss: -0.2089, Accuracy : 12381/14395 (86.01%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 26 [0/500 (0%)]	Loss1: 0.001627	 mccloss_t1: 0.000086
# Train Epoch: 26 [100/500 (20%)]	Loss1: 0.001104	 mccloss_t1: 0.000006
# Train Epoch: 26 [200/500 (40%)]	Loss1: 0.001108	 mccloss_t1: 0.000094
# Train Epoch: 26 [300/500 (60%)]	Loss1: 0.001482	 mccloss_t1: 0.000027
# Train Epoch: 26 [400/500 (80%)]	Loss1: 0.000879	 mccloss_t1: 0.000083
#
# Test set: Average loss: -0.2095, Accuracy : 12467/14395 (86.61%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 27 [0/500 (0%)]	Loss1: 0.000723	 mccloss_t1: 0.000021
# Train Epoch: 27 [100/500 (20%)]	Loss1: 0.000920	 mccloss_t1: 0.000050
# Train Epoch: 27 [200/500 (40%)]	Loss1: 0.001188	 mccloss_t1: 0.000062
# Train Epoch: 27 [300/500 (60%)]	Loss1: 0.000962	 mccloss_t1: 0.000190
# Train Epoch: 27 [400/500 (80%)]	Loss1: 0.001342	 mccloss_t1: 0.000073
#
# Test set: Average loss: -0.2097, Accuracy : 12549/14395 (87.18%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 28 [0/500 (0%)]	Loss1: 0.001265	 mccloss_t1: 0.000012
# Train Epoch: 28 [100/500 (20%)]	Loss1: 0.000951	 mccloss_t1: 0.000024
# Train Epoch: 28 [200/500 (40%)]	Loss1: 0.001816	 mccloss_t1: 0.000051
# Train Epoch: 28 [300/500 (60%)]	Loss1: 0.001725	 mccloss_t1: 0.000140
# Train Epoch: 28 [400/500 (80%)]	Loss1: 0.000686	 mccloss_t1: 0.000390
#
# Test set: Average loss: -0.2104, Accuracy : 12430/14395 (86.35%)
#
# recording : ./record/2_23:42:28
# Train Epoch: 29 [0/500 (0%)]	Loss1: 0.001027	 mccloss_t1: 0.000086
# Train Epoch: 29 [100/500 (20%)]	Loss1: 0.001323	 mccloss_t1: 0.000010
# Train Epoch: 29 [200/500 (40%)]	Loss1: 0.001366	 mccloss_t1: 0.000045
# Train Epoch: 29 [300/500 (60%)]	Loss1: 0.001007	 mccloss_t1: 0.000029
# Train Epoch: 29 [400/500 (80%)]	Loss1: 0.001015	 mccloss_t1: 0.000091
#
# Test set: Average loss: -0.2107, Accuracy : 12481/14395 (86.70%)
#
# recording : ./record/2_23:42:28

# %%
mat1 = bestmat/bestmat.sum(axis=1 ,keepdims = True)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
sns.heatmap(data=mat1,annot=True,cmap= "YlGnBu")
# Out:
# <AxesSubplot:>
