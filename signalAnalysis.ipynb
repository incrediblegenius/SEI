# %%
import h5py
import numpy as np

eminame = '780609'
dic = dict()
with h5py.File('./dataset/alldata_resample64x64.h5', 'r') as f :
    s1 = np.array(f[eminame][:])



with h5py.File('./dataset/alldata_Preprocess64x64.h5', 'r') as f :
    s2 = np.array(f[eminame][:])

print(dic)
# Out:
# {}

# %% [markdown]
# **keys: '780063', '780070', '780277', '78027b', '78027c', '780291', '7802b1', '78048b', '78048f', '7804bc', '7804ea', '7804f5', '78050f', '780534', '7805c3', '780609', '780635', '780649', '7807cb', '780800', '780830', '780831', '78087a', '7809a3', '780b69', '780c2d', '780cbc', '780d19', '780d8c', '780db4', '780df9', '780dfa', '780fb6', '780fe3'**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.DataFrame(s1[:30])
sig_num = len(df)
print(sig_num)
corr = df.T.corr(method='pearson')
# m = np.zeros((sig_num,sig_num))



# m = m/m.sum(axis=1 ,keepdims = True)
plt.figure(figsize=(15,15))
sns.heatmap(data=corr,annot=True,cmap= "YlGnBu")
# Out:
# 30
# <AxesSubplot:>
