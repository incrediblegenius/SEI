# %%
import h5py
import numpy as np
import torch
from ResNet import resnet50,resnet152
with h5py.File('original_64x64.h5','r') as f:
    X_train = np.array(f['X_train'][:])
    y_train = np.array(f['y_train'][:])
    X_test = np.array(f['X_test'][:])
    y_test = np.array(f['y_test'][:])
print(len(X_train),len(y_train))
print(len(X_test),len(y_test))
# Out:
# 23835 23835
# 10215 10215

# %%
import matplotlib.pyplot as plt
X_c1 = [ X_train[i]  for i in range(len(X_train)) if y_train[i] == 5]
plt.figure(figsize=(10,10))
for i in range(5):
    plt.subplot(5,1,i+1)
    plt.plot(X_c1[i+5])
plt.show()

# %%
from collections import Counter
Counter(y_test)
# Out:
# Counter({6: 254,
#          28: 585,
#          29: 187,
#          8: 362,
#          26: 403,
#          16: 398,
#          3: 346,
#          23: 672,
#          4: 298,
#          21: 333,
#          7: 368,
#          1: 373,
#          12: 274,
#          5: 246,
#          19: 142,
#          13: 296,
#          2: 279,
#          11: 276,
#          0: 230,
#          33: 376,
#          15: 254,
#          9: 276,
#          31: 284,
#          17: 304,
#          27: 417,
#          20: 57,
#          30: 107,
#          25: 313,
#          32: 271,
#          18: 230,
#          14: 190,
#          24: 254,
#          10: 332,
#          22: 228})

# %% [markdown]
# Counter({18: 486,
#          29: 405,
#          2: 669,
#          17: 668,
#          33: 875,
#          8: 845,
#          16: 964,
#          28: 1329,
#          26: 1003,
#          11: 615,
#          31: 665,
#          30: 251,
#          3: 860,
#          6: 642,
#          27: 1073,
#          4: 694,
#          10: 770,
#          9: 677,
#          21: 800,
#          7: 909,
#          1: 847,
#          13: 567,
#          19: 389,
#          23: 1546,
#          32: 632,
#          5: 517,
#          15: 559,
#          25: 700,
#          14: 410,
#          0: 517,
#          12: 679,
#          22: 529,
#          24: 605,
#          20: 138})
